# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#datasets path

#AD100

TRAIN_PATH_AD = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/AD100/train.csv"
TEST_PATH_AD = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/AD100/verification-subject-disjoint.csv"
IMAGE_PATH_AD = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/AD100/images/"
IMAGE_PATH_AD_AUG = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/AD100/images_aug/"

#LG4000

TRAIN_PATH_LG = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/LG4000/train.csv"
TEST_PATH_LG = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/LG4000/verification-subject-disjoint.csv"
IMAGE_PATH_LG = "/content/drive/MyDrive/datasets/ND-Contact-Lens/ND-Contact-Lens/LG4000/images/"

# %%
#Classifier Functions

contacts_classifier = {
    "No": [0, 0, 1],
    "Yes": [0, 1, 0],
    "Cosmetic" : [1, 0, 0]
}

eye_classifier = {
    "Right": [0, 1],
    "Left": [1, 0]
}

# %%
import pandas as pd

df = pd.read_csv(TRAIN_PATH_LG)
df.head(5)
# Out:
#         Image    Subject    Eye Gender   Race Contacts  PupilX  PupilY  \
# 0  04261d1016  nd1S04261   Left   Male  White      Yes     320     234
# 1  04261d1033  nd1S04261  Right   Male  White      Yes     327     248
# 2  04261d1036  nd1S04261  Right   Male  White      Yes     324     236
# 3  04261d1142  nd1S04261   Left   Male  White      Yes     323     234
# 4  04261d1319  nd1S04261   Left   Male  White      Yes     316     235
#
#    PupilR  IrisX  IrisY  IrisR  Fold
# 0      35    323    234    124     6
# 1      39    321    246    122     3
# 2      40    318    233    132     3
# 3      37    331    235    130     6
# 4      39    322    236    134     6

# %%
#Reading the data

def list_classes(filepath, name_class):
  df = pd.read_csv(filepath)

  class_list = list(df[name_class])

  return class_list

eye_classifiers = list_classes(TRAIN_PATH_LG, "Eye")
contacts_classifiers = list_classes(TRAIN_PATH_LG, "Contacts")
print(eye_classifiers)
print(contacts_classifiers)
# Out:
# ['Left', 'Right', 'Right', 'Left', 'Left', 'Left', 'Right', 'Left', 'Left', 'Right', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Right', 'Right', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Right', 'Left', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Left', 'Right', 'Left', 'Right', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Right', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Left', 'Right', 'Left', 'Left', 'Right', 'Left', 'Right', 'Right', 'Left', 'Right', 'Left', 'Right', 'Left', 'Left', 'Right', 'Right', 'Left', 'Left', 'Right', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Left', 'Left', 'Left', 'Left', 'Right', ...
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No ...

# %%
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import os
import numpy as np


def make_data(filepath, imagepath = IMAGE_PATH_LG, augmentation=False, dict_eye = eye_classifier, dict_contacts = contacts_classifier):
  images_names = os.listdir(imagepath)

  eye_classification = list_classes(filepath, "Eye")
  contacts_classification = list_classes(filepath, "Contacts")

  images = []
  eye_label, contacts_label = [], []

  index = -1
  for item in images_names:
    index+=1
    if(index == len(eye_classification)):
      break
    image = load_img(imagepath + item, target_size=(224, 224, 3, 1))
    image = img_to_array(image) / 255.0


    eye_list = dict_eye[eye_classification[index]]
    contact_list = dict_contacts[contacts_classification[index]]

    images.append(image)
    eye_label.append(eye_list)
    contacts_label.append(contact_list)

    if augmentation:
      datagen = ImageDataGenerator(
          rotation_range=10,
          zoom_range=0.1,
      )

      i = 0
      for batch in datagen.flow(image, batch_size=8, save_to_dir=IMAGE_PATH_AD_AUG, save_prefix="aug_image", save_format="tiff"):
        images.append(batch)
        eye_label.append(eye_list)
        contacts_label.append(contact_list)

        i+=1
        if i == 8:
          break

  return np.array(images).astype(np.float32), np.array(eye_label).astype(np.int32), np.array(contacts_label).astype(np.int32)

# %%
x_train, y_train_eye, y_train_contact = make_data(TRAIN_PATH_LG)
x_test, y_test_eye, y_test_contact = make_data(TEST_PATH_LG)

print(f"Train: {x_train.shape} \t Eye_Label: {y_train_eye.shape} \t Contact_Label: {y_train_contact.shape}\n")
print(f"Test: {x_test.shape} \t Eye_Label: {y_test_eye.shape} \t Contact_Label: {y_test_contact.shape}\n")
# Out:
# Train: (3000, 224, 224, 3) 	 Eye_Label: (3000, 2) 	 Contact_Label: (3000, 3)
#
# Test: (1200, 224, 224, 3) 	 Eye_Label: (1200, 2) 	 Contact_Label: (1200, 3)

# %%
from keras.applications import VGG16, MobileNet, InceptionV3, ResNet101, InceptionResNetV2, EfficientNetB3

base_model = EfficientNetB3(include_top=False, weights='imagenet',  classifier_activation=None)
for layer in base_model.layers:
  layer.trainable = True


base_model.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling (Rescaling)       (None, None, None, 3)        0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, None, None, 3)        7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, None, None, 3)        0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, None, None, 3)        0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, None, None, 40)       1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, None, None, 40)       160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, None, None, 40)       0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, None, None, 40)       360       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, None, None, 40)       160       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, None, None, 40)       0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 40)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 40)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 10)             410       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 40)             440       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, None, None, 40)       0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, None, None, 24)       960       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, None, None, 24)       96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, None, None, 24)       216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, None, None, 24)       96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, None, None, 24)       0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, None, None, 24)       0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, None, None, 24)       576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, None, None, 24)       96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, None, None, 24)       0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, None, None, 24)       0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, None, None, 144)      3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, None, None, 144)      576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, None, None, 144)      0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, None, None, 144)      0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, None, None, 144)      1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, None, None, 144)      576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, None, None, 144)      0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, None, None, 144)      0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, None, None, 32)       4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, None, None, 32)       128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, None, None, 192)      6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, None, None, 192)      768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, None, None, 192)      0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, None, None, 192)      1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, None, None, 192)      768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, None, None, 192)      0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, None, None, 192)      0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, None, None, 32)       6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, None, None, 32)       128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, None, None, 32)       0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, None, None, 32)       0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, None, None, 192)      6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, None, None, 192)      768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, None, None, 192)      0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, None, None, 192)      1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, None, None, 192)      768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, None, None, 192)      0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, None, None, 192)      0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, None, None, 32)       6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, None, None, 32)       128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, None, None, 32)       0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, None, None, 32)       0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, None, None, 192)      6144      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, None, None, 192)      768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, None, None, 192)      0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, None, None, 192)      0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, None, None, 192)      4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, None, None, 192)      768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, None, None, 192)      0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, None, None, 192)      0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, None, None, 48)       9216      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, None, None, 48)       192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, None, None, 288)      13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, None, None, 288)      1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, None, None, 288)      0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, None, None, 288)      7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, None, None, 288)      1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, None, None, 288)      0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, None, None, 288)      0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, None, None, 48)       13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, None, None, 48)       192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, None, None, 48)       0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, None, None, 48)       0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, None, None, 288)      13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, None, None, 288)      1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, None, None, 288)      0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, None, None, 288)      7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, None, None, 288)      1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, None, None, 288)      0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, None, None, 288)      0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, None, None, 48)       13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, None, None, 48)       192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, None, None, 48)       0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, None, None, 48)       0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, None, None, 288)      13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, None, None, 288)      1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, None, None, 288)      0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, None, None, 288)      0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, None, None, 288)      2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, None, None, 288)      1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, None, None, 288)      0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, None, None, 288)      0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, None, None, 96)       27648     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, None, None, 96)       384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, None, None, 576)      55296     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, None, None, 576)      2304      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, None, None, 576)      0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, None, None, 576)      5184      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, None, None, 576)      2304      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, None, None, 576)      0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 576)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, None, None, 576)      0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, None, None, 96)       55296     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, None, None, 96)       384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, None, None, 96)       0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, None, None, 96)       0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, None, None, 576)      55296     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, None, None, 576)      2304      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, None, None, 576)      0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, None, None, 576)      5184      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, None, None, 576)      2304      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, None, None, 576)      0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 576)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, None, None, 576)      0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, None, None, 96)       55296     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, None, None, 96)       384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, None, None, 96)       0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, None, None, 96)       0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, None, None, 576)      55296     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, None, None, 576)      2304      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, None, None, 576)      0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, None, None, 576)      5184      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, None, None, 576)      2304      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, None, None, 576)      0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 576)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4d_se_reduce[0][0]']
#
# ...
#  tion)
#
#  block6e_activation (Activa  (None, None, None, 1392)     0         ['block6e_bn[0][0]']
#  tion)
#
#  block6e_se_squeeze (Global  (None, 1392)                 0         ['block6e_activation[0][0]']
#  AveragePooling2D)
#
#  block6e_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, None, None, 1392)     0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, None, None, 232)      322944    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, None, None, 232)      928       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, None, None, 232)      0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, None, None, 232)      0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, None, None, 1392)     322944    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, None, None, 1392)     5568      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, None, None, 1392)     0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv (DepthwiseC  (None, None, None, 1392)     34800     ['block6f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6f_bn (BatchNormaliza  (None, None, None, 1392)     5568      ['block6f_dwconv[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, None, None, 1392)     0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1392)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, None, None, 1392)     0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, None, None, 232)      322944    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, None, None, 232)      928       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, None, None, 232)      0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, None, None, 232)      0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, None, None, 1392)     322944    ['block6f_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, None, None, 1392)     5568      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, None, None, 1392)     0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, None, None, 1392)     12528     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, None, None, 1392)     5568      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, None, None, 1392)     0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1392)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, None, None, 1392)     0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, None, None, 384)      534528    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, None, None, 384)      1536      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, None, None, 2304)     884736    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, None, None, 2304)     9216      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, None, None, 2304)     0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, None, None, 2304)     20736     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, None, None, 2304)     9216      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, None, None, 2304)     0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2304)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, None, None, 2304)     0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, None, None, 384)      884736    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, None, None, 384)      1536      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, None, None, 384)      0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, None, None, 384)      0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, None, None, 1536)     589824    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, None, None, 1536)     6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, None, None, 1536)     0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 10783535 (41.14 MB)
# Trainable params: 10696232 (40.80 MB)
# Non-trainable params: 87303 (341.03 KB)
# __________________________________________________________________________________________________

# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, LeakyReLU


def generate_model(base_model):

  input_layer = Input(shape=(224, 224, 3))

  base_model = base_model (input_layer)

  batch_norm = BatchNormalization() (base_model)
  global_pooling = GlobalAveragePooling2D() (batch_norm)

  dropout1 = Dropout(0.1)(global_pooling)
  dense1 = Dense(1024, activation=LeakyReLU())(dropout1)

  dropout2 = Dropout(0.1)(dense1)
  dense2 = Dense(512, activation=LeakyReLU())(dropout2)

  final_dropout = Dropout(0.1)(dense2)
  final_dense   = Dense(512, activation=LeakyReLU())(final_dropout)

  #contacts layer
  contacts_layer = Dense(3, activation='softmax', name="contacts_layer")(final_dense)

  #eye layer
  eye_layer = Dense(2, activation='sigmoid', name="eye_layer")(final_dense)

  model = Model(inputs= input_layer, outputs=[eye_layer, contacts_layer])

  return model


model = generate_model(base_model)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  efficientnetb3 (Functional  (None, None, None, 1536)     1078353   ['input_2[0][0]']
#  )                                                        5
#
#  batch_normalization (Batch  (None, 7, 7, 1536)           6144      ['efficientnetb3[0][0]']
#  Normalization)
#
#  global_average_pooling2d (  (None, 1536)                 0         ['batch_normalization[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 1024)                 1573888   ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 512)                  524800    ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  262656    ['dropout_2[0][0]']
#
#  eye_layer (Dense)           (None, 2)                    1026      ['dense_2[0][0]']
#
#  contacts_layer (Dense)      (None, 3)                    1539      ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 13153588 (50.18 MB)
# Trainable params: 13063213 (49.83 MB)
# Non-trainable params: 90375 (353.03 KB)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import RMSprop, Adam, SGD
from keras.optimizers.schedules import ExponentialDecay
from keras.losses import BinaryCrossentropy, CategoricalCrossentropy

learning_rates = [0.001, 0.0001]
epochs = 20
batch_size = 10

decay_factor = (learning_rates[1] / learning_rates[0]) / epochs
decay_steps = int(len(x_train) / batch_size)

learning_rate = ExponentialDecay(
    initial_learning_rate= learning_rates[0],
    decay_steps= decay_steps,
    decay_rate=decay_factor,
    staircase=True
)

optimizer = Adam(learning_rate=learning_rate)


losses = {
    'eye_layer': BinaryCrossentropy(),
    'contacts_layer': CategoricalCrossentropy()
}

model.compile(optimizer= optimizer, loss= losses, metrics= 'accuracy')

# %%
history = model.fit(x_train, [y_train_eye, y_train_contact], epochs= epochs, batch_size=batch_size, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/20
# 240/240 [==============================] - 116s 200ms/step - loss: 1.6318 - eye_layer_loss: 0.7118 - contacts_layer_loss: 0.9200 - eye_layer_accuracy: 0.5050 - contacts_layer_accuracy: 0.5217 - val_loss: 1.5823 - val_eye_layer_loss: 0.6931 - val_contacts_layer_loss: 0.8892 - val_eye_layer_accuracy: 0.4783 - val_contacts_layer_accuracy: 0.9967
# Epoch 2/20
# 240/240 [==============================] - 43s 181ms/step - loss: 1.4758 - eye_layer_loss: 0.6965 - contacts_layer_loss: 0.7793 - eye_layer_accuracy: 0.5088 - contacts_layer_accuracy: 0.6071 - val_loss: 4.3386 - val_eye_layer_loss: 0.6943 - val_contacts_layer_loss: 3.6443 - val_eye_layer_accuracy: 0.5167 - val_contacts_layer_accuracy: 0.0000e+00
# Epoch 3/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3968 - eye_layer_loss: 0.6884 - contacts_layer_loss: 0.7084 - eye_layer_accuracy: 0.5346 - contacts_layer_accuracy: 0.6408 - val_loss: 3.1089 - val_eye_layer_loss: 0.6925 - val_contacts_layer_loss: 2.4165 - val_eye_layer_accuracy: 0.5200 - val_contacts_layer_accuracy: 0.2800
# Epoch 4/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3985 - eye_layer_loss: 0.6902 - contacts_layer_loss: 0.7083 - eye_layer_accuracy: 0.5267 - contacts_layer_accuracy: 0.6488 - val_loss: 2.0435 - val_eye_layer_loss: 0.6944 - val_contacts_layer_loss: 1.3491 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6533
# Epoch 5/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3816 - eye_layer_loss: 0.6926 - contacts_layer_loss: 0.6890 - eye_layer_accuracy: 0.5175 - contacts_layer_accuracy: 0.6488 - val_loss: 1.9847 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.2900 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6733
# Epoch 6/20
# 240/240 [==============================] - 44s 185ms/step - loss: 1.3901 - eye_layer_loss: 0.6890 - contacts_layer_loss: 0.7012 - eye_layer_accuracy: 0.5392 - contacts_layer_accuracy: 0.6479 - val_loss: 2.0648 - val_eye_layer_loss: 0.6946 - val_contacts_layer_loss: 1.3702 - val_eye_layer_accuracy: 0.5267 - val_contacts_layer_accuracy: 0.6667
# Epoch 7/20
# 240/240 [==============================] - 45s 189ms/step - loss: 1.4018 - eye_layer_loss: 0.6900 - contacts_layer_loss: 0.7118 - eye_layer_accuracy: 0.5342 - contacts_layer_accuracy: 0.6446 - val_loss: 2.0912 - val_eye_layer_loss: 0.6946 - val_contacts_layer_loss: 1.3966 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6650
# Epoch 8/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3907 - eye_layer_loss: 0.6898 - contacts_layer_loss: 0.7009 - eye_layer_accuracy: 0.5379 - contacts_layer_accuracy: 0.6529 - val_loss: 2.0233 - val_eye_layer_loss: 0.6946 - val_contacts_layer_loss: 1.3287 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6683
# Epoch 9/20
# 240/240 [==============================] - 44s 183ms/step - loss: 1.3964 - eye_layer_loss: 0.6892 - contacts_layer_loss: 0.7072 - eye_layer_accuracy: 0.5342 - contacts_layer_accuracy: 0.6404 - val_loss: 1.9969 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.3022 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6717
# Epoch 10/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.4005 - eye_layer_loss: 0.6880 - contacts_layer_loss: 0.7126 - eye_layer_accuracy: 0.5462 - contacts_layer_accuracy: 0.6438 - val_loss: 1.9988 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.3040 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6733
# Epoch 11/20
# 240/240 [==============================] - 44s 183ms/step - loss: 1.4006 - eye_layer_loss: 0.6888 - contacts_layer_loss: 0.7118 - eye_layer_accuracy: 0.5404 - contacts_layer_accuracy: 0.6425 - val_loss: 2.0261 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.3314 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6683
# Epoch 12/20
# 240/240 [==============================] - 44s 185ms/step - loss: 1.4068 - eye_layer_loss: 0.6873 - contacts_layer_loss: 0.7196 - eye_layer_accuracy: 0.5392 - contacts_layer_accuracy: 0.6408 - val_loss: 1.9795 - val_eye_layer_loss: 0.6949 - val_contacts_layer_loss: 1.2846 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6800
# Epoch 13/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.4020 - eye_layer_loss: 0.6879 - contacts_layer_loss: 0.7141 - eye_layer_accuracy: 0.5437 - contacts_layer_accuracy: 0.6413 - val_loss: 2.0187 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.3239 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6700
# Epoch 14/20
# 240/240 [==============================] - 44s 183ms/step - loss: 1.4037 - eye_layer_loss: 0.6889 - contacts_layer_loss: 0.7148 - eye_layer_accuracy: 0.5396 - contacts_layer_accuracy: 0.6542 - val_loss: 2.0335 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.3388 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6683
# Epoch 15/20
# 240/240 [==============================] - 44s 185ms/step - loss: 1.3998 - eye_layer_loss: 0.6893 - contacts_layer_loss: 0.7105 - eye_layer_accuracy: 0.5467 - contacts_layer_accuracy: 0.6529 - val_loss: 2.0341 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.3393 - val_eye_layer_accuracy: 0.5300 - val_contacts_layer_accuracy: 0.6717
# Epoch 16/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3971 - eye_layer_loss: 0.6903 - contacts_layer_loss: 0.7068 - eye_layer_accuracy: 0.5304 - contacts_layer_accuracy: 0.6642 - val_loss: 2.0322 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.3374 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6700
# Epoch 17/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.4058 - eye_layer_loss: 0.6902 - contacts_layer_loss: 0.7156 - eye_layer_accuracy: 0.5300 - contacts_layer_accuracy: 0.6529 - val_loss: 2.0313 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.3366 - val_eye_layer_accuracy: 0.5317 - val_contacts_layer_accuracy: 0.6717
# Epoch 18/20
# 240/240 [==============================] - 44s 185ms/step - loss: 1.4019 - eye_layer_loss: 0.6892 - contacts_layer_loss: 0.7127 - eye_layer_accuracy: 0.5354 - contacts_layer_accuracy: 0.6521 - val_loss: 1.9782 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.2834 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6817
# Epoch 19/20
# 240/240 [==============================] - 44s 185ms/step - loss: 1.3904 - eye_layer_loss: 0.6900 - contacts_layer_loss: 0.7004 - eye_layer_accuracy: 0.5379 - contacts_layer_accuracy: 0.6529 - val_loss: 2.0093 - val_eye_layer_loss: 0.6947 - val_contacts_layer_loss: 1.3146 - val_eye_layer_accuracy: 0.5283 - val_contacts_layer_accuracy: 0.6767
# Epoch 20/20
# 240/240 [==============================] - 44s 184ms/step - loss: 1.3917 - eye_layer_loss: 0.6867 - contacts_layer_loss: 0.7050 - eye_layer_accuracy: 0.5471 - contacts_layer_accuracy: 0.6554 - val_loss: 1.9889 - val_eye_layer_loss: 0.6948 - val_contacts_layer_loss: 1.2941 - val_eye_layer_accuracy: 0.5267 - val_contacts_layer_accuracy: 0.6800

# %%
evaluation = model.evaluate(x_test, [y_test_eye, y_test_contact], verbose=1)
# Out:
# 38/38 [==============================] - 11s 158ms/step - loss: 2.7967 - eye_layer_loss: 0.7041 - contacts_layer_loss: 2.0926 - eye_layer_accuracy: 0.5092 - contacts_layer_accuracy: 0.3408

# %%
print("Eye's Prediction:     ",evaluation[3] * 100,"%")
print("Contact's Prediction: ",evaluation[4] * 100,"%")
# Out:
# Eye's Prediction:      50.91666579246521 %
# Contact's Prediction:  34.08333361148834 %
